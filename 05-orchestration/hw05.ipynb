# %%
! curl -XPUT -H "Content-Type: application/json" http://localhost:9200/_cluster/settings -d '{ "transient": { "cluster.routing.allocation.disk.threshold_enabled": false } }'
# Out:
# {"acknowledged":true,"persistent":{},"transient":{"cluster":{"routing":{"allocation":{"disk":{"threshold_enabled":"false"}}}}}}

# %%
! curl -XPUT -H "Content-Type: application/json" http://localhost:9200/_all/_settings -d '{"index.blocks.read_only_allow_delete": null}'
# Out:
# {"error":{"root_cause":[{"type":"index_not_found_exception","reason":"no such index [null] and no indices exist","resource.type":"index_expression","resource.id":"_all"}],"type":"index_not_found_exception","reason":"no such index [null] and no indices exist","resource.type":"index_expression","resource.id":"_all"},"status":404}

# %% [markdown]
# # Q1

# %%
from IPython.display import Image
Image(filename='mage_version.PNG')

# %% [markdown]
# # Q2

# %%
Image(filename='hw5_q2.PNG')

# %% [markdown]
# # Q3

# %%
Image(filename='hw5_q3.PNG')

# %% [markdown]
# # Q4

# %%
Image(filename='hw5_q4.PNG')

# %% [markdown]
# # Q5

# %%
from elasticsearch import Elasticsearch

es_client = Elasticsearch('http://localhost:9200')

# %%
index_name = 'documents_20240813_2547'
query = 'When is the next cohort?'

search_query = {
    "size": 1,
    "query": {
        "bool": {
            "must": {
                "multi_match": {
                    "query": query,
                }
            },
        }
    }
}

response = es_client.search(index=index_name, body=search_query)

# %%
response['hits']['hits'][0]
# Out:
# {'_index': 'documents_20240813_2547',
#  '_id': 'mdszSpEBqHgJ7kAnGMcY',
#  '_score': 8.443945,
#  '_source': {'text': 'Summer 2025 (via Alexey).',
#   'section': 'General course-related questions',
#   'question': 'When will the course be offered next?',
#   'course': 'llm-zoomcamp',
#   'document_id': 'bf024675'}}

# %% [markdown]
# # Q6

# %%
index_name = 'documents_20240813_3014'
query = 'When is the next cohort?'

search_query = {
    "size": 1,
    "query": {
        "bool": {
            "must": {
                "multi_match": {
                    "query": query,
                }
            },
        }
    }
}

response = es_client.search(index=index_name, body=search_query)

# %%
response['hits']['hits'][0]
# Out:
# {'_index': 'documents_20240813_3014',
#  '_id': '79s3SpEBqHgJ7kAnK8dx',
#  '_score': 17.212463,
#  '_source': {'text': 'Summer 2026.',
#   'section': 'General course-related questions',
#   'question': 'When is the next cohort?',
#   'course': 'llm-zoomcamp',
#   'document_id': 'b6fa77f3'}}
